# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from datetime import datetime
from sklearn import metrics
from scipy import stats
import scikitplot as skplt # pip install scikit-plot

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
import statsmodels.api as sm
import statsmodels

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data importation

# %%
df_init = pd.read_csv('dataset_SCL.csv')

# %%
df_init
# Out:
#                    Fecha-I Vlo-I Ori-I Des-I Emp-I              Fecha-O  \
# 0      2017-01-01 23:30:00   226  SCEL  KMIA   AAL  2017-01-01 23:33:00
# 1      2017-01-02 23:30:00   226  SCEL  KMIA   AAL  2017-01-02 23:39:00
# 2      2017-01-03 23:30:00   226  SCEL  KMIA   AAL  2017-01-03 23:39:00
# 3      2017-01-04 23:30:00   226  SCEL  KMIA   AAL  2017-01-04 23:33:00
# 4      2017-01-05 23:30:00   226  SCEL  KMIA   AAL  2017-01-05 23:28:00
# ...                    ...   ...   ...   ...   ...                  ...
# 68201  2017-12-22 14:55:00   400  SCEL  SPJC   JAT  2017-12-22 15:41:00
# 68202  2017-12-25 14:55:00   400  SCEL  SPJC   JAT  2017-12-25 15:11:00
# 68203  2017-12-27 14:55:00   400  SCEL  SPJC   JAT  2017-12-27 15:35:00
# 68204  2017-12-29 14:55:00   400  SCEL  SPJC   JAT  2017-12-29 15:08:00
# 68205  2017-12-31 14:55:00   400  SCEL  SPJC   JAT  2017-12-31 15:04:00
#
#        Vlo-O Ori-O Des-O Emp-O  DIA  MES   AÑO     DIANOM TIPOVUELO  \
# ...

# %% [markdown]
# # Data Distribution

# %% [markdown]
# All variables are categorical, then value_counts is used in order to know percentages per category

# %%
all_vars = df_init.columns.to_list()
all_vars.remove("Fecha-I") #alone is not a feature
all_vars.remove("Fecha-O") #alone is not a feature
all_vars.remove("Vlo-I") #flight identifier, alone it cant be used as feature
all_vars.remove("Vlo-O") #flight identifier, alone it cant be used as feature

for var in all_vars:
    print(f"Variable: {var}")
    print(f"Number of categories: {len(df_init[var].unique())}")
    print(df_init[var].value_counts(normalize = True))
    print("\n")
# Out:
# Variable: Ori-I
# Number of categories: 1
# SCEL    1.0
# Name: Ori-I, dtype: float64
#
#
# Variable: Des-I
# Number of categories: 64
# SCFA    0.084846
# SPJC    0.077266
# SCCF    0.075433
# SCTE    0.063880
# SCIE    0.058573
#           ...
# SBFI    0.000015
# SPSO    0.000015
# SEQU    0.000015
# SEQM    0.000015
# SARI    0.000015
# Name: Des-I, Length: 64, dtype: float64
#
#
# Variable: Emp-I
# Number of categories: 30
# LAN    0.551432
# SKU    0.209630
# TAM    0.044703
# ARG    0.028575
# CMP    0.027124
# LAW    0.023077
# AVA    0.016890
# JAT    0.016054
# GLO    0.011817
# AAL    0.011099
# ACA    0.008284
# IBE    0.005307
# AFR    0.005249
# DAL    0.005249
# AMX    0.005146
# UAL    0.004912
# ONE    0.004091
# AZA    0.003797
# KLM    0.003680
# LAP    0.003167
# BAW    0.003006
# QFU    0.002859
# JMR    0.001466
# LRC    0.001349
# AUT    0.001085
# PUE    0.000718
# LXP    0.000132
# LPE    0.000059
# DSM    0.000029
# LNE    0.000015
# ...

# %% [markdown]
# Observations:
#
# 1- Ori-I, Ori-O, SIGLAORI are formed by a single category, then it cant be used as a feature
#
# 2- Des-I, Des-O, Emp-I, Emp-O, OPERA, SIGLADES are formed by 64, 63, 30, 32, 23, 62 categories respectively, but there are a lot of categories with less than 5% of participation. Using these variables as "raw features" is not a good practice. A solution can be drop rows for  minoritary categories or REGROUP these categories in only one category. For example, Emp-O has only 3 categories (of 32) with more than 5% of participation, so a new variable could be formed using 3 majority categories and another category (regroup 29)  for the rest.
#
# 3- AÑO and DIA present the same problem described in 2- . AÑO has only 1 majority category, then it cant be used as feature. DIA does not have categories with at least 5 % of participation
#
# 4- TIPOVUELO, MES, DIANOM are formed by categories with at least 5 % of participation. These variables do not need changes

# %% [markdown]
# # Synthetic features

# %%
df_init['Fecha-I'] = pd.to_datetime(df_init['Fecha-I'])
df_init['Fecha-O'] = pd.to_datetime(df_init['Fecha-O'])

# High season
df_init['high_season'] = 0
df_init.loc[((df_init['Fecha-I'].dt.month == 12) & (df_init['Fecha-I'].dt.day >= 15))
            | ((df_init['Fecha-I'].dt.month == 3) & (df_init['Fecha-I'].dt.day <= 4))
            | (df_init['Fecha-I'].dt.month.isin([1, 2]))
            | (df_init['Fecha-I'].dt.month == 7 & df_init['Fecha-I'].dt.day.between(15, 31))
            | (df_init['Fecha-I'].dt.month == 9 & df_init['Fecha-I'].dt.day.between(11, 30))
            , 'high_season'] = 1

# Minute difference
df_init['min_diff'] = (df_init['Fecha-O'] - df_init['Fecha-I']).dt.total_seconds()/60

# Delay 15 min
df_init['delay_15'] = 0
df_init.loc[(df_init['min_diff']>15), 'delay_15'] = 1

# Period of the day 
df_init['period_day'] = None
df_init.loc[df_init['Fecha-I'].dt.strftime('%H:%M').between('05:00', '11:59'), 'period_day'] = 'morning'
df_init.loc[df_init['Fecha-I'].dt.strftime('%H:%M').between('12:00', '18:59'), 'period_day'] = 'afternoon'
df_init.loc[(df_init['Fecha-I'].dt.strftime('%H:%M').between('19:00', '23:59'))
            | (df_init['Fecha-I'].dt.strftime('%H:%M').between('00:00', '04:59'))
            , 'period_day'] = 'night'

df_init[['high_season', 'min_diff', 'delay_15', 'period_day']].to_csv('synthetic_features.csv') # export to csv

# %%
df_init['delay_15'].value_counts(normalize = True)
# Out:
# 0    0.81506
# 1    0.18494
# Name: delay_15, dtype: float64

# %% [markdown]
# We will have an unbalanced problem, but delayed flights represent a significant participation (18%)

# %% [markdown]
# # Behavior
#
# Given a categorical variable of n categories. For the i-th category (between 1 to n), **Information Value** is defined by
#
# $$IV_i = (n_{\text{events}} - n_{\text{non-events}}) \text{log}(\frac{n_{\text{events}}}{n_{\text{non-events}}})$$
#
# where $n_{j}$ for j in (events, non-events) is the distribution of events or non-events inside the i-th category. An event in this problem is a delayed flight and a non-event is a non delayed flight.
#
# The term $$\text{log}(\frac{n_{\text{events}}}{n_{\text{non-events}}})$$ is called **Weight of Evidence (WoE)** of this category and **can be used to codify the categories**
#
#
# Finally, Global Information value for a categorical variable is defined by:
#
# $$IV = \sum_{i=1}^{n} IV_i $$
#
# IV per variable can be seen as "prediction power" using an objective variable as reference (delay_15 in this problem).
#
# Assumptions:
#
# - IV < 0.02 means a very weak variable (variable can be removed)
#
# - IV in [0.02, 0.3] means acceptable "power prediction"
#
# - IV > 0.3 means a very strong variable

# %% [markdown]
# ## Behavior utils

# %%
def compute_rates(data, variables: list):
    
    """
    compute event and non-event rate and IV per variable
    """

    var_name = variables[0]
    target_name = variables[1]
    
    df = data[[target_name, var_name]].copy() 
    dt = data[[target_name, var_name]].copy()
    
    woetable = df[var_name].value_counts(sort=False).reset_index()
    woetable.columns = ['Bin','Count']
    woetable['Count (%)'] = woetable['Count']/sum(woetable['Count'])
    tt = pd.crosstab(df[var_name],df[target_name]).reset_index()    
    tt.columns = ['Bin','Non-event','Event']
    woetable = woetable.merge(tt, on=['Bin'], how='left')
    woetable['Event rate'] = woetable['Event']/woetable['Count']

    #WoE distribution
    dist_b = woetable['Non-event'] / woetable['Non-event'].sum()
    dist_m = woetable['Event'] / woetable['Event'].sum()

    with warnings.catch_warnings():  # zero division
        warnings.simplefilter("ignore")
        woetable['WoE'] = np.log(dist_b / dist_m)

    woetable['IV'] = (dist_b - dist_m) * woetable['WoE']

    diccionario = dict(zip(woetable['Bin'], woetable['WoE']))    
    woe = dt[var_name]
    woe.replace(diccionario, inplace=True)

    woetable = woetable.append({'Bin': 'Missing', 'Count': 0, 
                'Event': 0}, ignore_index=True)
    woetable.loc[(woetable['Bin'] == 'Missing'), 'Count (%)'] = 0
    woetable.loc[(woetable['Bin'] == 'Missing'), 'Non-event'] = 0
    woetable.loc[(woetable['Bin'] == 'Missing'), 'Event rate'] = 0
    woetable.loc[(woetable['Bin'] == 'Missing'), 'WoE'] = 0
    woetable.loc[(woetable['Bin'] == 'Missing'), 'IV'] = 0

    df_iv = woetable.copy() 
    df_iv['Variable'] = var_name
    
    return df_iv

def plot_events(df_iv, title, include_missing=True):
    
    """
    Plot events and non-events per bin (category)
    """

    _, ax1 = plt.subplots(figsize=(10,5))

    df_iv['Bin'] = df_iv['Bin'].astype(str)
    n_events = np.concatenate((
        df_iv[df_iv['Bin'].isin(['Missing'])]['Event'],
        df_iv[~df_iv['Bin'].isin(['', 'Special', 'Missing'])]['Event']
    ))

    n_non_events = np.concatenate((
        df_iv[df_iv['Bin'].isin(['Missing'])]['Non-event'],
        df_iv[~df_iv['Bin'].isin(['', 'Special', 'Missing'])]['Non-event']
    ))

    n_events_rate = np.concatenate((
        df_iv[df_iv['Bin'].isin(['Missing'])]['Event rate'],
        df_iv[~df_iv['Bin'].isin(['', 'Special', 'Missing'])]['Event rate']
    ))

    bins = np.concatenate((np.array(['missing']),
        df_iv[~df_iv['Bin'].isin(['', 'Special', 'Missing'])]['Bin'])) if include_missing \
        else df_iv[~df_iv['Bin'].isin(['', 'Special', 'Missing'])]['Bin']

    p2 = ax1.bar(bins, n_events, width = 0.5)
    p1 = ax1.bar(bins, n_non_events, width = 0.5,
                        bottom = n_events)

    handles = [p1[0], p2[0]]
    labels = ['Non delayed flight', 'Delayed Flight']

    ax1.set_xlabel("Bin", fontsize=12)
    ax1.set_ylabel("Number of examples per bin", fontsize=13)
    ax2 = ax1.twinx()
    
    ax1.set_xticklabels(bins, rotation=90, ha='right')

    ax2.plot(bins, n_events_rate,
    linestyle="solid", marker="o", color="black")
    ax2.set_ylabel('Delay rate', fontsize=13)

    for idx, bin_item in enumerate(bins):
        percentage = '{:.1f}%'.format(100 * n_events_rate[idx])
        ax2.annotate(percentage, (bin_item, n_events_rate[idx]+0.005), size = 8,
            ha = 'center', va = 'center', 
            xytext = (0, 9), 
            textcoords = 'offset points'
            )
    ax2.set_ylim(0, np.max(n_events_rate)*1.1)
    plt.title(title, fontsize=14)
    plt.legend(handles, labels, loc="upper center",
              bbox_to_anchor=(0.5, -0.2), ncol=2, fontsize=12)
    plt.xticks(rotation = 90)

# %% [markdown]
# ## Behavior results and observations
#
# Raw variables are plotted in order to see the impact of non-significant categories described inj the section "Data distribution"

# %%
for var in ['SIGLADES', 'OPERA']:
    df_iv = compute_rates(df_init, [var, 'delay_15'])
    plot_events(df_iv, var, include_missing=True)

# %% [markdown]
# SIGLADES and OPERA for example show minoritary categories (less than 5 % of participation) with higher delay rate. In conclusion, these variables are regrouped as was described in "Data distribution" section
#
# _mod is added in the variable name to identify regrouped variable
#
# **Note that "missing" bin is added** in order to include empty data as a different category, but in this case missing does not exist

# %%
mod_vars = ['Des-I', 'Des-O', 'Emp-I', 'Emp-O', 'OPERA', 'SIGLADES'] # reagrouped variables

for var in mod_vars:
    perc = pd.DataFrame({'Category': df_init[var].value_counts(normalize=True).index.to_list(),
                    '%': df_init[var].value_counts(normalize=True).values
                    })

    perc = perc[perc['%']<0.05]

    df_init[f'{var}_mod'] = df_init[var].values
    df_init.loc[df_init[f'{var}_mod'].isin(perc['Category'].values), f'{var}_mod'] = 'Other'
    

iv_list = []
variables = ['Des-I_mod', 'Des-O_mod', 'Emp-I_mod', 'Emp-O_mod', 'OPERA_mod', 'SIGLADES_mod', #regrouped variables 
             'MES', 
             'DIANOM', 
             'high_season', 
             'TIPOVUELO',
             'period_day']

df_iv_global = None
for var in variables:
    df_iv = compute_rates(df_init, [var, 'delay_15'])
    iv_list.append(df_iv['IV'].sum())
    plot_events(df_iv, var, include_missing=True)
    
    df_iv_global = pd.concat([df_iv[df_iv['Bin']!='Missing'], df_iv_global])
    
df_iv_sort = pd.DataFrame({'Variable': variables, 'IV': iv_list}) # Information value
df_iv_sort.sort_values(by = 'IV', inplace = True, ascending = False)
df_iv_sort.reset_index(inplace = True)
df_iv_sort.drop(['index'], axis =  1, inplace = True)

# %%
df_iv_sort # table with sorted information value
# Out:
#         Variable        IV
# 0            MES  0.112294
# 1      TIPOVUELO  0.061398
# 2   SIGLADES_mod  0.057764
# 3      Des-O_mod  0.041190
# 4      Des-I_mod  0.041085
# 5      Emp-O_mod  0.037203
# 6         DIANOM  0.021111
# 7      Emp-I_mod  0.018559
# 8     period_day  0.016519
# 9      OPERA_mod  0.007667
# 10   high_season  0.000193

# %% [markdown]
# Behaviors:
#
# - Airline:
#
# 1- OPERA_mod shows Grupo LATAM and Sky Airline are the airlines with greater delay rate compared to the rest as only 1 category. Information Value is 0.007, then is a very weak variable
#
# 2- Emp-O_mod has greater IV than Emp-I_mod and shows that the airlines codes in "other" category (that are not SKU, LAN and LXP) are the most delayed
#
# These 3 variables explain the same thing (airline) and the greater IV is Emp-O_mod, so OPERA_mod and EMP-I_mod are dropped
#
# - Destination:
#
# 1- SIGLADES_mod shows Buenos Aires, Lima and Sao Paulo as the destiny cities with greater delay rate (23-25% approx)
#
# 2- Des-I_mod Des-O_mod shows SBGR and SPJC are the destination codes with greater delay rate
#
# These 3 variables explain the same thing (destination) and the greater IV is SIGLADES_mod, so Des-I_mod Des-O_mod are dropped
#
# - Month of the year:
#
# 1- MES plot shows July and December as the months with greater delay rate
#
# - Day of the week:
#
# 1- DIANOM plot shows Lunes and Viernes as the days with greater delay rate. However, in general the delay rate are similar the 7 days and the weak Information value of 0.02 (see table) make sense.
#
# - Season:
#
# 1- high_season plot shows poor discrimination power (18% of delay rate in both cases). Compared to the month, MES is a significant best variable.
#
# - Type of flight:
#
# 1- TIPOVUELO plot shows an international flight has significant delay rate compared to a national flight (22% vs 15%)
#
# - Period of the day:
#
# 1- Night and afternoon are very similar (see period_day plot) and morning has the lowest delay rate. The variable in general is poor (due to night and afternoon similarity), which explains the poor IV (0.01)
#
#
# MES, TIPOVUELO and SIGLADES_mod are the strongest variables

# %% [markdown]
# # Model
#
# Logit (Logistic regression) and Probit models (both from statsmodels) are used in this part
#
# Given a set of features x, then these models compute a probability of class c as $\Phi(x|c)$ where $\Phi(x|c) = \frac{1}{1+\text{exp}(-w^Tx)}$ for Logit model ($w$ is the vector of coefficients/weights). Probit model assumes this function is the cumulative distribution function of the standard normal distribution

# %% [markdown]
# ## Categorical variables codes

# %% [markdown]
# Each category is encoded using its WoE (Weight of Evidence) previously defined. Note that lower/higher WoE means lower/higher delay rate, then it is a reasonable choice

# %%
selected_vars = ['Emp-O_mod', 'SIGLADES_mod', #regrouped variables 
             'MES', 
             'DIANOM', 
             'high_season', 
             'TIPOVUELO',
             'period_day']

df_pre_model = df_init[selected_vars].copy()


for var in selected_vars:
    df_pre_model[var] = df_pre_model[var].astype('str')
    
    df_iv_var = df_iv_global[df_iv_global['Variable'] == var].copy()
    df_iv_var = df_iv_var.rename(columns={"Bin": var})
    
    df_pre_model[var] = df_pre_model[[var]].copy().merge(df_iv_var, on = [var], how='left')['WoE'].values

df_pre_model['delay_15'] = df_init['delay_15'].values
df_pre_model
# Out:
#        Emp-O_mod  SIGLADES_mod       MES    DIANOM  high_season  TIPOVUELO  \
# 0      -0.246016      0.027377  0.174119  0.166937     0.025354  -0.249954
# 1      -0.246016      0.027377  0.174119 -0.110333     0.025354  -0.249954
# 2      -0.246016      0.027377  0.174119  0.108672     0.025354  -0.249954
# 3      -0.246016      0.027377  0.174119  0.096386     0.025354  -0.249954
# 4      -0.246016      0.027377  0.174119 -0.093764     0.025354  -0.249954
# ...          ...           ...       ...       ...          ...        ...
# 68201  -0.246016     -0.276955 -0.406319 -0.229282     0.025354  -0.249954
# 68202  -0.246016     -0.276955 -0.406319 -0.110333     0.025354  -0.249954
# 68203  -0.246016     -0.276955 -0.406319  0.096386     0.025354  -0.249954
# 68204  -0.246016     -0.276955 -0.406319 -0.229282     0.025354  -0.249954
# 68205  -0.246016     -0.276955 -0.406319  0.166937     0.025354  -0.249954
#
#        period_day  delay_15
# 0       -0.097082         0
# ...

# %% [markdown]
# ## Metrics
#
# The metrics to use are the following:
#
# ROC Curve: defined as a plot true positive rate (true delayed flights in this problem) vs false positive rate (true delayed flights in this problem)
#
# AUC: Area under the ROC Curve (1 is the perfect model)
#
# Kolmogorov Smirnov (KS): defined as the max difference between the 2 cumulative distribution functions (both classes). This metric is not sensitive to unbalanced data and it allows to see if there is a statistical difference between both classes or the model classifies correctly by chance
#
# Recall: % of positives that the model classifies correctly. This metric is not sensitive to unbalanced data and allows you to see the precise part of the objective class that classifies correctly

# %% [markdown]
# ## Utils
# Functions:
# - Data split into train and test
# - Model fit and evaluate performance

# %%
def split_data(df, target_name, test_size=0.3, sampler = None):
    """
    Data split into train and test
    """

    X_train, X_test, _, _ = train_test_split(df, df[target_name], test_size=test_size, shuffle=True,
                                                  random_state=42, stratify=df[target_name])
                                                  #stratify assure similar class proportion between train and test
    X_train['DataSplit'] = 1
    
    if sampler == 'under': #undersampling
        ros = RandomUnderSampler(random_state=0)
        X_train, _= ros.fit_resample(X_train, X_train['delay_15'].values)
    
    elif sampler == 'over': #oversampling
        ros = RandomOverSampler(random_state=0)
        X_train, _= ros.fit_resample(X_train, X_train['delay_15'].values)
    
    X_test['DataSplit'] = 0
    data = pd.concat([X_train, X_test])
    data = data.sample(frac=1.0, random_state=42)
    
    # return the original dataframe with a new column 'DataSplit' which is 1 if its a train example 0 otherwise
    return data

# %%
def log_prob_model(df, target, sampling, model_type = 'log'):
    """
    Logit (Logistic regression) or Probit model 
    
    Stats model is used (instead of sklearn) due to its train information
    (coefficients and p-value associated)
    """
    mask_muestra = df[sampling] == 1
    variables = df.columns.to_list()
    variables.remove(target)
    variables.remove(sampling)
    
    X = sm.add_constant(df.loc[mask_muestra, variables].copy())
    y = df.loc[mask_muestra, target].copy()
    
    if model_type == 'log':
        model = sm.Logit(y, X)
    else:
        model = statsmodels.discrete.discrete_model.Probit(y, X)
        
    result_model = model.fit(disp=0) #train
    rr = result_model.summary2()
    table_1, table_2 = rr.tables
    
    return table_1, table_2, result_model

# %%
def model_performance(df, variables, target, fitted_model, cut, sampling,
                       test_index):
    
    """
    Compute ROC and KS Curve,
    Recall, AUC and KS value
    """

    X = df.loc[df[sampling] == test_index, variables].copy()
    X = sm.add_constant(X)
    y = df.loc[df[sampling] == test_index, target].copy()

    if test_index == 0:
        mm = 'Test'
    else:
        mm = 'Train'

    yhat = fitted_model.predict(X)
    y_probas = fitted_model.predict(X)
    y_probas = np.transpose(np.concatenate(
        [[y_probas], [1-y_probas]], axis=0))[:, ::-1]
    base_analisis = pd.DataFrame()
    base_analisis = pd.concat([y, yhat], axis=1)
    base_analisis.columns = ['y', 'prob']
    
    # cut quantiles (=10 deciles) for ks compute
    ser, bins = pd.qcut(
        base_analisis['prob'], cut, retbins=True, labels=False, duplicates='drop')
    base_analisis['cut'] = pd.cut(
        base_analisis['prob'], bins=bins, labels=False, include_lowest=True)

    # KS table summary
    kstable = pd.DataFrame()
    kstable['Bucket'] = sorted(base_analisis['cut'].unique())
    kstable['Count'] = (base_analisis.groupby(
        'cut', as_index=False).agg({'y': "count"}))['y']
    kstable['Non-event'] = 0
    kstable['Event'] = (base_analisis.groupby(
        'cut', as_index=False).agg({'y': "sum"}))['y']
    kstable['Non-event'] = kstable['Count']-kstable['Event']
    kstable['Event rate'] = kstable['Event']/kstable['Count']
    kstable = kstable.sort_values(by=['Event rate'], ascending=False)
    kstable['Odds'] = kstable['Non-event']/kstable['Event']
    dist_b = kstable['Non-event']/kstable['Non-event'].sum()
    dist_m = kstable['Event']/kstable['Event'].sum()
    kstable['WOE'] = np.log(dist_b/dist_m)
    kstable['IV'] = (dist_b-dist_m)*kstable['WOE']
    kstable['Dist Non-event'] = dist_b
    kstable['Dist Event'] = dist_m
    kstable['Non-event Acum'] = dist_b.cumsum()
    kstable['Event Acum'] = dist_m.cumsum()
    kstable['KS'] = (kstable['Non-event Acum'] - kstable['Event Acum']).abs()

    # KS point by point
    ks = stats.ks_2samp(base_analisis.loc[base_analisis.y == 0, "prob"],
                        base_analisis.loc[base_analisis.y == 1, "prob"]).statistic

    fpr, tpr, thresholds = metrics.roc_curve(y, yhat)
    roc_auc = metrics.auc(fpr, tpr)
    
    roc = metrics.roc_auc_score(y, yhat)
    
    recall = metrics.recall_score(y, list(map(round, yhat)))
    
    cm = metrics.confusion_matrix(y, list(map(round, yhat))) 

    # ROC Curve
    fig = plt.figure(figsize=(6, 5))
    ax = fig.add_subplot(111)
    ax.plot(fpr, tpr)
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.0])
    ax.set_title(f'ROC curve - {mm}', fontsize=14)
    ax.set_xlabel('False Positive Rate', fontsize=12)
    ax.set_ylabel('True Positive Rate', fontsize=12)

    xpos = ax.get_xlim()[0] + 0.97*(ax.get_xlim()[1] - ax.get_xlim()[0])
    ypos = ax.get_xlim()[0] + 0.05*(ax.get_xlim()[1] - ax.get_xlim()[0])
    ax.text(xpos, ypos, f'AUC = {roc_auc:.4f}\nKS = {ks:.4f}\nRecall = {recall:.4f}',
            ha='right', va='bottom', fontsize=12,
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
    fig.tight_layout()


    # KS Curve
    fig = plt.figure(figsize=(6, 5))
    ax = skplt.metrics.plot_ks_statistic(
        y, y_probas, title=f'KS Curve - {mm}')
    ax.legend()

    return kstable, ks, roc, recall, cm

# %% [markdown]
# ## Unbalanced data
#
# First, logistic model is trained using the original data proportion
#
# 30% is used due to the amount of data (40% could be used for example with balanced problem and a larger number of examples)

# %%
df_unbalanced = split_data(df_pre_model, 'delay_15', test_size = 0.3)

print('Train %')
print(df_unbalanced[df_unbalanced['DataSplit'] == 0]['delay_15'].value_counts(normalize = True))
print('\n')
print('Test %')
print(df_unbalanced[df_unbalanced['DataSplit'] == 1]['delay_15'].value_counts(normalize = True))
# Out:
# Train %
# 0    0.815072
# 1    0.184928
# Name: delay_15, dtype: float64
#
#
# Test %
# 0    0.815055
# 1    0.184945
# Name: delay_15, dtype: float64

# %% [markdown]
# Train and test have similar proportions (approx 81% and 18% from non-delayed and delayed respectively)

# %%
table_1, table_2, resultado = log_prob_model(df_unbalanced, 'delay_15', 'DataSplit')
table_2
# Out:
#                  Coef.  Std.Err.           z          P>|z|    [0.025  \
# const        -1.484184  0.012122 -122.432187   0.000000e+00 -1.507943
# Emp-O_mod    -0.295897  0.082298   -3.595414   3.238757e-04 -0.457199
# SIGLADES_mod -0.595243  0.068207   -8.727051   2.613994e-18 -0.728926
# MES          -1.000842  0.035953  -27.837611  1.521519e-170 -1.071308
# DIANOM       -1.119149  0.081995  -13.648964   2.047678e-42 -1.279857
# high_season   1.602468  0.869903    1.842123   6.545714e-02 -0.102510
# TIPOVUELO    -0.468819  0.080167   -5.847993   4.975390e-09 -0.625944
# period_day   -1.105394  0.095960  -11.519378   1.053692e-30 -1.293471
#
#                 0.975]
# const        -1.460424
# Emp-O_mod    -0.134595
# SIGLADES_mod -0.461561
# MES          -0.930376
# DIANOM       -0.958441
# high_season   3.307447
# TIPOVUELO    -0.311693
# period_day   -0.917317

# %% [markdown]
# **Coef.** represents log-odds coefficients of the logistic model and **P>|z|** represents p-value associated with a test over its coef. (coef. = zero as null hypothesis)
#
# As shown in the table, high_season has positive coefficient and p-value 6% approx (>5%), which means its coefficient should be zero. In conclusion, high_season is expendable, it could be removed
#
# The coefficients **do not mean "importance"**, relative importance can be used with this purpose (this is done at the end)

# %%
variables = df_unbalanced.columns.to_list()
variables.remove('delay_15')
variables.remove('DataSplit')
kstable, ks, roc, recall, cm = model_performance(df_unbalanced, variables, 'delay_15', resultado, 10, 'DataSplit', 0)

print('Confusion matrix: \n')
cm
# Out:
# Confusion matrix:
# array([[16678,     0],
#        [ 3784,     0]], dtype=int64)

# %% [markdown]
# Dotted line represents graphically KS value (max vertical distance between the 2 curves/classes)
#
# - KS = 0.2 represents a very poor performance, it shows there is not a stadistical difference between the 2 classes. At least KS = 0.4 is desired
#
# - AUC = 0.63 shows poor performance. At least AUC = 0.7 is desired
#
# - Confusion matrix and recall show that the model predicts only 1 class (non-delayed)

# %% [markdown]
# ## Oversampling
#
# if n_min is the number of examples of the minoritary class. Oversampling repeat examples of the minoritary class until balance the data

# %%
df_over = split_data(df_pre_model, 'delay_15', test_size = 0.3, sampler = 'over')

print('Train %')
print(df_over[df_over['DataSplit'] == 1]['delay_15'].value_counts(normalize = True))
print('\n')
print('Test %')
print(df_over[df_over['DataSplit'] == 0]['delay_15'].value_counts(normalize = True))
# Out:
# Train %
# 0    0.5
# 1    0.5
# Name: delay_15, dtype: float64
#
#
# Test %
# 0    0.815072
# 1    0.184928
# Name: delay_15, dtype: float64

# %% [markdown]
# Train data is balanced and test data has the original proportion

# %%
table_1, table_2, result_model_over = log_prob_model(df_over, 'delay_15', 'DataSplit')
table_2
# Out:
#                  Coef.  Std.Err.          z          P>|z|    [0.025    0.975]
# const        -0.001557  0.007377  -0.211086   8.328199e-01 -0.016016  0.012902
# Emp-O_mod    -0.349680  0.050145  -6.973400   3.093712e-12 -0.447962 -0.251398
# SIGLADES_mod -0.637550  0.042163 -15.121173   1.174328e-51 -0.720187 -0.554912
# MES          -0.999934  0.022301 -44.837091   0.000000e+00 -1.043644 -0.956223
# DIANOM       -1.166357  0.050906 -22.912120  3.517974e-116 -1.266130 -1.066584
# high_season   1.073687  0.532377   2.016781   4.371834e-02  0.030248  2.117126
# TIPOVUELO    -0.453161  0.048466  -9.350090   8.757304e-21 -0.548152 -0.358169
# period_day   -1.154328  0.058028 -19.892488   4.727103e-88 -1.268062 -1.040595

# %% [markdown]
# The same behavior is observed (compared to balanced data)

# %%
variables = df_over.columns.to_list()
variables.remove('delay_15')
variables.remove('DataSplit')
kstable, ks, roc, recall, cm = model_performance(df_over, variables, 'delay_15', result_model_over, 10, 'DataSplit', 0)

print('Confusion matrix: \n')
cm
# Out:
# Confusion matrix:
# array([[10165,  6513],
#        [ 1551,  2233]], dtype=int64)

# %% [markdown]
# KS and AUC are very similar to the values obtained for the unbalanced data (poor performance). Recall = 0.5901 shows best performance compared to unbalanced data

# %% [markdown]
# ## Undersampling
#
# if n_min is the number of examples of the minoritary class. Undersampling chooses only n_min examples of the majority class (randomly) in order to balance the data

# %%
df_under = split_data(df_pre_model, 'delay_15', test_size = 0.3, sampler = 'under')

print('Train %')
print(df_under[df_under['DataSplit'] == 1]['delay_15'].value_counts(normalize = True))
print('\n')
print('Test %')
print(df_under[df_under['DataSplit'] == 0]['delay_15'].value_counts(normalize = True))
# Out:
# Train %
# 1    0.5
# 0    0.5
# Name: delay_15, dtype: float64
#
#
# Test %
# 0    0.815072
# 1    0.184928
# Name: delay_15, dtype: float64

# %% [markdown]
# Train data is balanced and test data has the original proportion

# %%
table_1, table_2, result_model_under = log_prob_model(df_under, 'delay_15', 'DataSplit')
table_2
# Out:
#                  Coef.  Std.Err.          z          P>|z|    [0.025    0.975]
# const         0.000168  0.015495   0.010842   9.913494e-01 -0.030201  0.030537
# Emp-O_mod    -0.232148  0.105213  -2.206464   2.735156e-02 -0.438361 -0.025935
# SIGLADES_mod -0.567932  0.088368  -6.426889   1.302422e-10 -0.741131 -0.394734
# MES          -1.037332  0.046934 -22.102103  3.016844e-108 -1.129321 -0.945344
# DIANOM       -1.169759  0.106864 -10.946230   6.927114e-28 -1.379209 -0.960310
# high_season   1.140764  1.118696   1.019726   3.078583e-01 -1.051840  3.333368
# TIPOVUELO    -0.598609  0.101527  -5.896064   3.722755e-09 -0.797597 -0.399620
# period_day   -1.063385  0.121919  -8.722086   2.731229e-18 -1.302342 -0.824429

# %% [markdown]
# The same behavior is observed (compared to unbalanced data)

# %%
variables = df_under.columns.to_list()
variables.remove('delay_15')
variables.remove('DataSplit')
kstable, ks, roc, recall, cm = model_performance(df_under, variables, 'delay_15', result_model_under, 10, 'DataSplit', 0)

print('Confusion matrix: \n')
cm
# Out:
# Confusion matrix:
# array([[10112,  6566],
#        [ 1542,  2242]], dtype=int64)

# %% [markdown]
# KS and AUC are very similar to the values obtained for the unbalanced data (poor performance). Recall = 0.5925 shows best performance compared to unbalanced data and is slightly better compared to oversampling data

# %% [markdown]
# ## Probit model
#
# We used undersampling directly due to its performance for the logistic model

# %%
table_1_prob, table_2_prob, result_model_under_prob = log_prob_model(df_under, 'delay_15', 'DataSplit', model_type = 'prob')
table_2_prob
# Out:
#                  Coef.  Std.Err.          z          P>|z|    [0.025    0.975]
# const        -0.000553  0.009594  -0.057592   9.540738e-01 -0.019357  0.018252
# Emp-O_mod    -0.143717  0.065230  -2.203248   2.757729e-02 -0.271565 -0.015869
# SIGLADES_mod -0.352727  0.054634  -6.456224   1.073475e-10 -0.459807 -0.245647
# MES          -0.641648  0.028783 -22.292236  4.394906e-110 -0.698063 -0.585234
# DIANOM       -0.724480  0.066056 -10.967608   5.470016e-28 -0.853948 -0.595012
# high_season   0.728683  0.694431   1.049325   2.940287e-01 -0.632376  2.089743
# TIPOVUELO    -0.370665  0.062949  -5.888374   3.900145e-09 -0.494041 -0.247288
# period_day   -0.657939  0.075467  -8.718199   2.826609e-18 -0.805852 -0.510026

# %% [markdown]
# The same behavior is observed (compared to balanced data)

# %%
variables = df_under.columns.to_list()
variables.remove('delay_15')
variables.remove('DataSplit')
kstable, ks, roc, recall, cm = model_performance(df_under, variables, 'delay_15', result_model_under_prob, 10, 'DataSplit', 0)

print('Confusion matrix: \n')
cm
# Out:
# Confusion matrix:
# array([[10148,  6530],
#        [ 1548,  2236]], dtype=int64)

# %% [markdown]
# Results are very similar compared to logistic model (trained with undersampling data). Recall is slightly greater in the logistic model

# %%
def relative_importance(table):
    """
    Relative importance plot
    """
    table = table.reset_index().rename(columns={'index': 'variable'})
    table = table.dropna(subset=['Coef. Rel.']).sort_values('Coef. Rel.')
    coef_rel = table[['variable', 'Coef. Rel.', 'P>|z|']].copy()

    idx = coef_rel.variable.values
    values = 100 * coef_rel["Coef. Rel."].values
    
    #plot
    h = round(len(idx)/4 + 0.5, 0)
    fig = plt.figure(figsize=(10, h))
    ax = fig.add_subplot()

    ax.barh(idx, values, align='center')

    values2 = coef_rel['P>|z|'].values
    
    for i, (v, v2) in enumerate(zip(values, values2)):
        ax.text(v, i, f'P={v2:.4f}', color="darkblue",
                horizontalalignment="left", size=8,
                verticalalignment="center")

    ax.set_title('Relative importance (%)')
    ax.set_xlim([ax.get_xlim()[0], 1.25*ax.get_xlim()[1]])

    fig.tight_layout()
    plt.show()
    plt.close()

# %% [markdown]
# ## Relative importance of each variable
#
# For the best model (Logistic model trained using undersampling data), relative importance is computed using the coefficients described previously.
#
# For i-th variable and its $w_i$ coefficient, relative importance is defined by the following:
#
# $$
# \text{relative importance} =  \frac{|w_i|}{\sum_{j=1}^{n} |w_j|}
# $$

# %%
mask = table_2.index != 'const'
table_2.loc[mask, 'Coef. Rel.'] = table_2.loc[mask, 'Coef.'].abs() / table_2.loc[mask, 'Coef.'].abs().sum()

relative_importance(table_2)

# %% [markdown]
# As the graph shows, DIANOM is the most important value for the trained model (approx 20% of relative importance). The variable high_season is the second but it was explained its high p-value previously
#
# period_day and MES are very similar (approx 17% of relative importance). The same behavior is observed for TIPOVUELO and SIGLADES_mod (approx 10% of relative importance)
#
# Emp-O_mod is the variable with the worst relative importance (< 5%)

# %% [markdown]
# Possible ways to improve performance:
#
# - Generate a lot of new synthetic features. It includes regroup the current variables. For example, in the variable period_day the categories 'night' and 'afternoon' can be only 1 category (due to its similar delay rate)
#
# - Experiments using new options as target (another options than 15 minutes). Another options will not necessarily have that much imbalance and may have better Information Value combined with current variables
